# %%
source("core.r")
# Out:
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.7     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
# Size of graphics
options(repr.plot.width=20, repr.plot.height=10)
jpeg(file=file.path(fig_folder, fig1_name), width=1200, height=600)
p1
dev.off()
p1
# Out:
# png
#   2
# plot without title

# %%
summary(modelo)
# Out:
# Call:
# lm(formula = Sepal.Length ~ Sepal.Width, data = df_iris)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.5561 -0.6333 -0.1120  0.5579  2.2226
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   6.5262     0.4789   13.63   <2e-16 ***
# Sepal.Width  -0.2234     0.1551   -1.44    0.152
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8251 on 148 degrees of freedom
# Multiple R-squared:  0.01382,	Adjusted R-squared:  0.007159
# F-statistic: 2.074 on 1 and 148 DF,  p-value: 0.1519

# %%
# Size of graphics
options(repr.plot.width=12, repr.plot.height=10)
jpeg(file=file.path(fig_folder, fig2_name), width=800, height=600)
p2
dev.off()
p2
# Out:
# png
#   2
# plot without title

# %%
# Size of graphics
options(repr.plot.width=20, repr.plot.height=10)
jpeg(file=file.path(fig_folder, fig3_name), width=1200, height=600)
p3
dev.off()
p3
# Out:
# png
#   2
# plot without title

# %%
summary(modelo2)
# Out:
# Call:
# lm(formula = Sepal.Length ~ Sepal.Width + Species, data = df_iris)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.30711 -0.25713 -0.05325  0.19542  1.41253
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)         2.2514     0.3698   6.089 9.57e-09 ***
# Sepal.Width         0.8036     0.1063   7.557 4.19e-12 ***
# Speciesversicolor   1.4587     0.1121  13.012  < 2e-16 ***
# Speciesvirginica    1.9468     0.1000  19.465  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.438 on 146 degrees of freedom
# Multiple R-squared:  0.7259,	Adjusted R-squared:  0.7203
# F-statistic: 128.9 on 3 and 146 DF,  p-value: < 2.2e-16

# %%
# Size of graphics
options(repr.plot.width=12, repr.plot.height=10)
jpeg(file=file.path(fig_folder, fig4_name), width=800, height=600)
p4
dev.off()
p4
# Out:
# png
#   2
# plot without title

# %%
anova(modelo, modelo2)
# Out:
#   Res.Df RSS       Df Sum of Sq F        Pr(>F)
# 1 148    100.75610 NA       NA        NA          NA
# 2 146     28.00366  2 72.75243  189.6512 2.55787e-41
