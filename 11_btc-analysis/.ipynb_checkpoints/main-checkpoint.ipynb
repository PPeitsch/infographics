# %%
source("modules.r")
# Out:
# Rows: 3189 Columns: 8
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# dbl  (7): Open, High, Low, Close, Volume, Dividends, Stock Splits
# dttm (1): Date
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 5716 Columns: 8
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# dbl  (7): Open, High, Low, Close, Volume, Dividends, Stock Splits
# dttm (1): Date
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 3938 Columns: 8
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# ...

# %%
str(combined_data)
# Out:
# 'data.frame':	2190 obs. of  31 variables:
#  $ Date         : Date, format: "2014-09-17" "2014-09-18" ...
#  $ Open_btc     : num  466 457 424 399 402 ...
#  $ High_btc     : num  468 457 428 407 442 ...
#  $ Low_btc      : num  452 413 385 397 396 ...
#  $ Close_btc    : num  457 424 395 402 436 ...
#  $ Volume_btc   : num  21056800 34483200 37919700 24127600 45099500 ...
#  $ Open_oro     : num  1236 1216 1218 1215 1221 ...
#  $ High_oro     : num  1236 1226 1218 1217 1221 ...
#  $ Low_oro      : num  1222 1216 1215 1212 1221 ...
#  $ Close_oro    : num  1234 1226 1215 1217 1221 ...
#  $ Volume_oro   : num  10 5 4 7 5 ...
#  $ Open_brent   : num  99 98.6 97.5 98.2 96.9 ...
#  $ High_brent   : num  99.5 99.1 98.5 98.2 97.6 ...
#  $ Low_brent    : num  98.5 97.4 97.2 96.4 96.6 ...
#  $ Close_brent  : num  99 97.7 98.4 97 96.8 ...
#  $ Volume_brent : num  14769 15316 12442 12582 13561 ...
#  $ Open_wti     : num  94.7 94 93 92.2 90.7 ...
# ...

# %%
other_close_prices <- subset(combined_data, select=c("Close_oro", "Close_brent", "Close_wti", "Close_sp500", "Close_nasdaq"))
correlation <- cor(combined_data$Close_btc, other_close_prices)

# %%
cor(combined_data$Close_sp500, combined_data$Close_nasdaq)
# Out:
# [1] 0.9853551

# %%
# Size of graphics
options(repr.plot.width=20, repr.plot.height=10)
jpeg(file=file.path(fig_folder, g1_name), width=1200, height=600)
g1
dev.off()
g1
# Out:
# png
#   2
# plot without title

# %%
# Size of graphics
options(repr.plot.width=20, repr.plot.height=10)
jpeg(file=file.path(fig_folder, g2_name), width=1200, height=600)
g2
dev.off()
g2
# Out:
# png
#   2
# plot without title

# %%
# Size of graphics
options(repr.plot.width=20, repr.plot.height=10)
jpeg(file=file.path(fig_folder, g3_name), width=1200, height=600)
g3
dev.off()
g3
# Out:
# png
#   2
# plot without title

# %%
# Size of graphics
options(repr.plot.width=20, repr.plot.height=10)
jpeg(file=file.path(fig_folder, g5_name), width=1200, height=600)
g5
dev.off()
g5
# Out:
# png
#   2
# plot without title

# %%
# Size of graphics
options(repr.plot.width=20, repr.plot.height=10)
jpeg(file=file.path(fig_folder, g7_name), width=1200, height=600)
g7
dev.off()
g7
# Out:
# png
#   2
# plot without title

# %%
# Size of graphics
options(repr.plot.width=20, repr.plot.height=10)
jpeg(file=file.path(fig_folder, m1_name), width=1200, height=600)
m1
dev.off()
m1
# Out:
# png
#   2
# plot without title

# %%
summary(model_1)
# Out:
# Call:
# lm(formula = Close_btc + Close_oro + Close_brent + Close_nasdaq ~
#     Date, data = df_model_1)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -18654  -8532  -3004   4961  45029
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -2.735e+05  4.969e+03  -55.05   <2e-16 ***
# Date         1.658e+01  2.768e-01   59.88   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 11940 on 2188 degrees of freedom
# Multiple R-squared:  0.621,	Adjusted R-squared:  0.6208
# F-statistic:  3585 on 1 and 2188 DF,  p-value: < 2.2e-16

# %%
# Size of graphics
options(repr.plot.width=20, repr.plot.height=10)
jpeg(file=file.path(fig_folder, m2_name), width=1200, height=600)
m2
dev.off()
m2
# Out:
# png
#   2
# plot without title

# %%
# Size of graphics
options(repr.plot.width=20, repr.plot.height=10)
jpeg(file=file.path(fig_folder, m3_name), width=1200, height=600)
m3
dev.off()
m3
# Out:
# png
#   2
# plot without title

# %%
summary(model_2)
# Out:
# Call:
# lm(formula = Close_btc ~ Date + Close_oro + Close_brent + Close_nasdaq,
#     data = df_model_2)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -15905.4  -2774.1    -56.3   2609.0  23416.5
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)   1.013e+05  4.996e+03  20.270  < 2e-16 ***
# Date         -7.805e+00  3.444e-01 -22.665  < 2e-16 ***
# Close_oro    -6.684e+00  1.095e+00  -6.107  1.2e-09 ***
# Close_brent   8.067e+01  7.532e+00  10.711  < 2e-16 ***
# Close_nasdaq  6.622e+00  9.503e-02  69.685  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 5374 on 2185 degrees of freedom
# Multiple R-squared:  0.8879,	Adjusted R-squared:  0.8877
# F-statistic:  4326 on 4 and 2185 DF,  p-value: < 2.2e-16

# %%
# Size of graphics
options(repr.plot.width=12, repr.plot.height=10)
jpeg(file=file.path(fig_folder, m4_name), width=800, height=600)
m4
dev.off()
m4
# Out:
# png
#   2
# plot without title

# %%
# Size of graphics
options(repr.plot.width=20, repr.plot.height=10)
jpeg(file=file.path(fig_folder, m5_name), width=1200, height=600)
m5
dev.off()
m5
# Out:
# png
#   2
# plot without title

# %%
summary(model_3)
# Out:
# Call:
# lm(formula = Close_btc ~ Close_oro * Date + Close_brent * Date +
#     Close_nasdaq * Date, data = df_model_3)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -14385.1  -2260.3   -177.5   1761.0  23262.0
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)        8.268e+04  2.398e+04   3.448 0.000576 ***
# Close_oro          1.543e+02  2.439e+01   6.327 3.03e-10 ***
# Date              -6.124e+00  1.351e+00  -4.534 6.11e-06 ***
# Close_brent       -9.448e+02  1.529e+02  -6.180 7.65e-10 ***
# Close_nasdaq      -1.921e+01  2.605e+00  -7.375 2.32e-13 ***
# Close_oro:Date    -9.109e-03  1.336e-03  -6.817 1.20e-11 ***
# Date:Close_brent   5.400e-02  8.486e-03   6.364 2.39e-10 ***
# Date:Close_nasdaq  1.397e-03  1.397e-04  10.002  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 5055 on 2182 degrees of freedom
# ...

# %%
# Size of graphics
options(repr.plot.width=12, repr.plot.height=10)
jpeg(file=file.path(fig_folder, m6_name), width=800, height=600)
m6
dev.off()
m6
# Out:
# png
#   2
# plot without title

# %%
anova(model_2, model_3)
# Out:
#   Res.Df RSS         Df Sum of Sq  F        Pr(>F)
# 1 2185   63108895913 NA         NA       NA           NA
# 2 2182   55767330862  3 7341565051 95.75077 3.217133e-58

# %%
# Third model
df_model_3 <- df_model_1
model_3 = lm(Close_btc ~ (Close_oro + Close_brent + Close_nasdaq)*Date, data=df_model_3)
df_model_3 <- add_predictions(data=df_model_3, model=model_3) %>% add_residuals(model=model_3)

# %%
# Third model
m5 <- ggplot(data=df_model_3) + 
        geom_point(aes(x=Date, y=Close_btc)) +
        geom_line(data=df_model_3, aes(x=Date, y=pred), color='Blue', size=1.5) +
        geom_line(data=df_model_3, aes(x=Date, y=Close_oro*30), color='Red', size=1.5) +
        theme(axis.line = element_line(colour = "black", size = 1), text = element_text(size = 30),
              plot.title = element_text(color="Black", size=30, face="bold")) +
        labs(x="Fecha (años)", y="Precio (u$s)", title="Regresion lineal: modelo 3")
# Residual graph
m6 <- ggplot(data=df_model_3, aes(y = resid)) +
        geom_boxplot() +
        labs(title='Boxplot: Residuals', y='Residuals value') +
        theme(axis.line = element_line(colour = "black", size = 1), text = element_text(size = 40),
              plot.title = element_text(color="Black", size=40, face="bold"))

# %%
m5
# Out:
# plot without title

# %%
m6
# Out:
# plot without title

# %%
ggplot(data1, aes(x = Close_btc, y = Volume_btc)) +
  geom_point(color = "#53868B") +
  labs(title = "Precio y Volumen del BTC",
       x = "Precio (USD)",
       y = "Volumen (USD)") +
  scale_y_continuous(labels = scales::comma_format()) +
  stat_smooth(color = "black") 
  theme(axis.line = element_line(colour = "black", size = 1), text = element_text(size = 10))

# %%
head(df_model_2)
# Out:
#   Date       Close_btc Volume_btc
# 1 2014-09-17 457.334   21056800
# 2 2014-09-18 424.440   34483200
# 3 2014-09-19 394.796   37919700
# 4 2014-09-22 402.152   24127600
# 5 2014-09-23 435.791   45099500
# 6 2014-09-24 423.205   30627700

# %%
residuals <- data.frame(m1_resid=df_model_1$resid, m2_resid=df_model_2$resid)
# Residual graph
m2 <- ggplot() +
        geom_boxplot(data=residuals, aes(color=resid)) +
        labs(title='Boxplot: Residuals', y='Residuals value') +
        theme(axis.line = element_line(colour = "black", size = 1), text = element_text(size = 40),
              plot.title = element_text(color="Black", size=40, face="bold"))
m2_name <- "m2.jpeg"

# %%
m2
# Out:
# Don't know how to automatically pick scale for object of type function. Defaulting to continuous.
#
# ERROR while rich displaying an object: Error in `f()`:
# ! Aesthetics must be valid data columns. Problematic aesthetic(s): colour = resid.
# Did you mistype the name of a data column or forget to add after_stat()?
#
# Traceback:
# 1. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 2. tryCatchList(expr, classes, parentenv, handlers)
# 3. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 4. doTryCatch(return(expr), name, parentenv, handler)
# 5. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
# ...

# %%
library(keras)
library(tensorflow)
# Out:
# Warning message:
# “package ‘keras’ was built under R version 4.2.3”

# %%
Close_btc ~ Close_oro + Close_brent + Close_nasdaq
Y = a*ORO + b*BRENT + c*NASDAQ
Y = a*ORO + b*BRENT + c*NASDAQ
# Out:
# Close_btc ~ Close_oro + Close_brent + Close_nasdaq
# Error in eval(expr, envir, enclos): object 'a' not found
# Traceback:
