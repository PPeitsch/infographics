# %%
source("modules.r")
# Out:
# Rows: 3189 Columns: 8
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# dbl  (7): Open, High, Low, Close, Volume, Dividends, Stock Splits
# dttm (1): Date
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 5716 Columns: 8
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# dbl  (7): Open, High, Low, Close, Volume, Dividends, Stock Splits
# dttm (1): Date
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 3938 Columns: 8
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# dbl  (7): Open, High, Low, Close, Volume, Dividends, Stock Splits
# dttm (1): Date
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 5726 Columns: 8
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# dbl  (7): Open, High, Low, Close, Volume, Dividends, Stock Splits
# dttm (1): Date
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 13201 Columns: 8
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# dbl  (7): Open, High, Low, Close, Volume, Dividends, Stock Splits
# dttm (1): Date
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 23975 Columns: 8
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# dbl  (7): Open, High, Low, Close, Volume, Dividends, Stock Splits
# dttm (1): Date
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 827 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# dbl  (1): FEDFUNDS
# date (1): DATE
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 305 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# dbl  (1): GDP
# date (1): DATE
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 905 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# dbl  (1): UNRATE
# date (1): DATE
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
str(combined_data)
# Out:
# tibble [2,190 × 31] (S3: tbl_df/tbl/data.frame)
#  $ Date         : Date[1:2190], format: "2014-09-17" "2014-09-18" ...
#  $ Open_btc     : num [1:2190] 466 457 424 399 402 ...
#  $ High_btc     : num [1:2190] 468 457 428 407 442 ...
#  $ Low_btc      : num [1:2190] 452 413 385 397 396 ...
#  $ Close_btc    : num [1:2190] 457 424 395 402 436 ...
#  $ Volume_btc   : num [1:2190] 21056800 34483200 37919700 24127600 45099500 ...
#  $ Open_oro     : num [1:2190] 1236 1216 1218 1215 1221 ...
#  $ High_oro     : num [1:2190] 1236 1226 1218 1217 1221 ...
#  $ Low_oro      : num [1:2190] 1222 1216 1215 1212 1221 ...
#  $ Close_oro    : num [1:2190] 1234 1226 1215 1217 1221 ...
#  $ Volume_oro   : num [1:2190] 10 5 4 7 5 ...
#  $ Open_brent   : num [1:2190] 99 98.6 97.5 98.2 96.9 ...
#  $ High_brent   : num [1:2190] 99.5 99.1 98.5 98.2 97.6 ...
#  $ Low_brent    : num [1:2190] 98.5 97.4 97.2 96.4 96.6 ...
#  $ Close_brent  : num [1:2190] 99 97.7 98.4 97 96.8 ...
#  $ Volume_brent : num [1:2190] 14769 15316 12442 12582 13561 ...
#  $ Open_wti     : num [1:2190] 94.7 94 93 92.2 90.7 ...
#  $ High_wti     : num [1:2190] 95.1 94.8 93.2 92.6 92.1 ...
#  $ Low_wti      : num [1:2190] 93.7 92.8 91.8 91.2 90.6 ...
#  $ Close_wti    : num [1:2190] 94.4 93.1 92.4 91.5 91.6 ...
#  $ Volume_wti   : num [1:2190] 305832 170772 92780 229232 247770 ...
#  $ Open_sp500   : num [1:2190] 1999 2003 2013 2009 1993 ...
#  $ High_sp500   : num [1:2190] 2011 2012 2019 2009 1995 ...
#  $ Low_sp500    : num [1:2190] 1993 2003 2007 1991 1983 ...
#  $ Close_sp500  : num [1:2190] 2002 2011 2010 1994 1983 ...
#  $ Volume_sp500 : num [1:2190] 3.21e+09 3.24e+09 4.88e+09 3.35e+09 3.28e+09 ...
#  $ Open_nasdaq  : num [1:2190] 4554 4576 4606 4568 4511 ...
#  $ High_nasdaq  : num [1:2190] 4582 4594 4611 4569 4536 ...
#  $ Low_nasdaq   : num [1:2190] 4539 4573 4563 4513 4508 ...
#  $ Close_nasdaq : num [1:2190] 4562 4593 4580 4528 4509 ...
#  $ Volume_nasdaq: num [1:2190] 1.80e+09 1.77e+09 3.18e+09 1.88e+09 1.85e+09 ...

# %%
g1
# Out:
# plot without title

# %%
g2
# Out:
# plot without title

# %%
g3
# Out:
# plot without title

# %%
g4
# Out:
# plot without title

# %%
m1
# Out:
# plot without title

# %%
m2
# Out:
# plot without title

# %%
m3
# Out:
# plot without title

# %%
m4
# Out:
# plot without title

# %%
# Third model
df_model_3 <- df_model_1
model_3 = lm(Close_btc ~ Date + Close_oro + Close_brent + Close_nasdaq, data=df_model_3)
df_model_3 <- add_predictions(data=df_model_3, model=model_3) %>% add_residuals(model=model_3)

# Third model
m5 <- ggplot(data=df_model_3) + 
        geom_point(aes(x=Date, y=Close_btc)) +
        geom_line(data=df_model_3, aes(x=Date, y=pred), color='Blue', size=1.5) +
        theme(axis.line = element_line(colour = "black", size = 1), text = element_text(size = 30),
              plot.title = element_text(color="Black", size=30, face="bold")) +
        labs(x="width", y="length", title="Sepal length and width")
# Residual graph
m6 <- ggplot(data=df_model_3, aes(y = resid)) +
        geom_boxplot() +
        labs(title='Boxplot: Residuals', y='Residuals value') +
        theme(axis.line = element_line(colour = "black", size = 1), text = element_text(size = 40),
              plot.title = element_text(color="Black", size=40, face="bold"))

# %%
library(keras)
library(tensorflow)
# Out:
# Error in library(keras): there is no package called ‘keras’
# Traceback:
#
# 1. library(keras)

# %%
# Second model
df_model_2 <- df_model_1
model_2 = lm(Close_btc ~ Date + Close_oro + Close_brent + Close_nasdaq, data=df_model_2)
df_model_2 <- add_predictions(data=df_model_2, model=model_2) %>% add_residuals(model=model_2)

# %%
# Second model
m3 <- ggplot(data=df_model_2) + 
        geom_point(aes(x=Date, y=Close_btc)) +
        geom_line(data=df_model_2, aes(x=Date, y=pred), color='Blue', size=1.5) +
        theme(axis.line = element_line(colour = "black", size = 1), text = element_text(size = 30),
              plot.title = element_text(color="Black", size=30, face="bold")) +
        labs(x="width", y="length", title="Sepal length and width")
# Residual graph
m4 <- ggplot(data=df_model_2, aes(y = resid)) +
        geom_boxplot() +
        labs(title='Boxplot: Residuals', y='Residuals value') +
        theme(axis.line = element_line(colour = "black", size = 1), text = element_text(size = 40),
              plot.title = element_text(color="Black", size=40, face="bold"))

# %%
m3
# Out:
# plot without title

# %%
Close_btc ~ Close_oro + Close_brent + Close_nasdaq
Y = a*ORO + b*BRENT + c*NASDAQ
Y = a*ORO + b*BRENT + c*NASDAQ

# %%
# Second model
df_model_2 <- df_model_1
model_2 = lm(Close_btc ~ Close_oro + Close_nasdaq, data=df_model_2)
df_model_2 <- add_predictions(data=df_model_2, model=model_2) %>% add_residuals(model=model_2)

# %%
# Second model
m3 <- ggplot(data=df_model_2) + 
        geom_point(aes(x=Date, y=Close_btc)) +
        geom_line(data=df_model_2, aes(x=Date, y=pred), color='Blue', size=1.5) +
        theme(axis.line = element_line(colour = "black", size = 1), text = element_text(size = 30),
              plot.title = element_text(color="Black", size=30, face="bold")) +
        labs(x="width", y="length", title="Sepal length and width")
# Residual graph
m4 <- ggplot(data=df_model_2, aes(y = resid)) +
        geom_boxplot() +
        labs(title='Boxplot: Residuals', y='Residuals value') +
        theme(axis.line = element_line(colour = "black", size = 1), text = element_text(size = 40),
              plot.title = element_text(color="Black", size=40, face="bold"))

# %%
m3
# Out:
# plot without title

# %%
combined_data_fed
