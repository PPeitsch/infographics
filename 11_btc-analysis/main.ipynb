# %%
source("core.r")
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.1.1       v purrr   0.3.2
# v tibble  2.1.1       v dplyr   0.8.0.1
# v tidyr   0.8.3       v stringr 1.4.0
# v readr   1.3.1       v forcats 0.4.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
#
# Attaching package: 'lubridate'
#
# The following object is masked from 'package:base':
#
#     date
#
# Parsed with column specification:
# cols(
#   Date = col_datetime(format = ""),
#   Open = col_double(),
#   High = col_double(),
#   Low = col_double(),
#   Close = col_double(),
#   Volume = col_double(),
#   Dividends = col_double(),
#   `Stock Splits` = col_double()
# )
# Parsed with column specification:
# cols(
#   Date = col_datetime(format = ""),
#   Open = col_double(),
#   High = col_double(),
#   Low = col_double(),
#   Close = col_double(),
#   Volume = col_double(),
#   Dividends = col_double(),
#   `Stock Splits` = col_double()
# )
# Parsed with column specification:
# cols(
#   Date = col_datetime(format = ""),
#   Open = col_double(),
#   High = col_double(),
#   Low = col_double(),
#   Close = col_double(),
#   Volume = col_double(),
#   Dividends = col_double(),
#   `Stock Splits` = col_double()
# )
# Parsed with column specification:
# cols(
#   Date = col_datetime(format = ""),
#   Open = col_double(),
#   High = col_double(),
#   Low = col_double(),
#   Close = col_double(),
#   Volume = col_double(),
#   Dividends = col_double(),
#   `Stock Splits` = col_double()
# )
# Parsed with column specification:
# cols(
#   Date = col_datetime(format = ""),
#   Open = col_double(),
#   High = col_double(),
#   Low = col_double(),
#   Close = col_double(),
#   Volume = col_double(),
#   Dividends = col_double(),
#   `Stock Splits` = col_double()
# )
# Parsed with column specification:
# cols(
#   Date = col_datetime(format = ""),
#   Open = col_double(),
#   High = col_double(),
#   Low = col_double(),
#   Close = col_double(),
#   Volume = col_double(),
#   Dividends = col_double(),
#   `Stock Splits` = col_double()
# )
# Parsed with column specification:
# cols(
#   DATE = col_date(format = ""),
#   FEDFUNDS = col_double()
# )
# Parsed with column specification:
# cols(
#   DATE = col_date(format = ""),
#   GDP = col_double()
# )
# Parsed with column specification:
# cols(
#   DATE = col_date(format = ""),
#   UNRATE = col_double()
# )
# Warning message:
# "Unknown or uninitialised column: 'Close_Brent'."Warning message:
# "Unknown or uninitialised column: 'Close_Nasdaq'."
# Error in data.frame(combined_data$Close_btc, combined_data$Close_oro, : arguments imply differing number of rows: 2190, 0
# Traceback:
#
# 1. source("core.r")
# 2. withVisible(eval(ei, envir))
# 3. eval(ei, envir)
# 4. eval(ei, envir)
# 5. data.frame(combined_data$Close_btc, combined_data$Close_oro,
#  .     combined_data$Close_Brent, combined_data$Close_Nasdaq)
# 6. stop(gettextf("arguments imply differing number of rows: %s",
#  .     paste(unique(nrows), collapse = ", ")), domain = NA)

# %%
source("modules.r")

# %%
str(combined_data)
# Out:
# 'data.frame':	2190 obs. of  31 variables:
#  $ Date         : Date, format: "2014-09-17" "2014-09-18" ...
#  $ Open_btc     : num  466 457 424 399 402 ...
#  $ High_btc     : num  468 457 428 407 442 ...
#  $ Low_btc      : num  452 413 385 397 396 ...
#  $ Close_btc    : num  457 424 395 402 436 ...
#  $ Volume_btc   : num  21056800 34483200 37919700 24127600 45099500 ...
#  $ Open_oro     : num  1236 1216 1218 1215 1221 ...
#  $ High_oro     : num  1236 1226 1218 1217 1221 ...
#  $ Low_oro      : num  1222 1216 1215 1212 1221 ...
#  $ Close_oro    : num  1234 1226 1215 1217 1221 ...
#  $ Volume_oro   : num  10 5 4 7 5 ...
#  $ Open_brent   : num  99 98.6 97.5 98.2 96.9 ...
#  $ High_brent   : num  99.5 99.1 98.5 98.2 97.6 ...
#  $ Low_brent    : num  98.5 97.4 97.2 96.4 96.6 ...
#  $ Close_brent  : num  99 97.7 98.4 97 96.8 ...
#  $ Volume_brent : num  14769 15316 12442 12582 13561 ...
#  $ Open_wti     : num  94.7 94 93 92.2 90.7 ...
#  $ High_wti     : num  95.1 94.8 93.2 92.6 92.1 ...
#  $ Low_wti      : num  93.7 92.8 91.8 91.2 90.6 ...
#  $ Close_wti    : num  94.4 93.1 92.4 91.5 91.6 ...
#  $ Volume_wti   : num  305832 170772 92780 229232 247770 ...
#  $ Open_sp500   : num  1999 2003 2013 2009 1993 ...
#  $ High_sp500   : num  2011 2012 2019 2009 1995 ...
#  $ Low_sp500    : num  1993 2003 2007 1991 1983 ...
#  $ Close_sp500  : num  2002 2011 2010 1994 1983 ...
#  $ Volume_sp500 : num  3.21e+09 3.24e+09 4.88e+09 3.35e+09 3.28e+09 ...
#  $ Open_nasdaq  : num  4554 4576 4606 4568 4511 ...
#  $ High_nasdaq  : num  4582 4594 4611 4569 4536 ...
#  $ Low_nasdaq   : num  4539 4573 4563 4513 4508 ...
#  $ Close_nasdaq : num  4562 4593 4580 4528 4509 ...
#  $ Volume_nasdaq: num  1.80e+09 1.77e+09 3.18e+09 1.88e+09 1.85e+09 ...

# %%
g1
# Out:
# plot without title

# %%
g2
# Out:
# plot without title

# %%
g3
# Out:
# plot without title

# %%
g4
# Out:
# plot without title

# %%
df_model_1 <- subset(combined_data, select=c("Date", "Close_btc", "Close_oro", "Close_brent", "Close_nasdaq"))
# First model
model_1 = lm( Close_btc + Close_oro + Close_brent + Close_nasdaq ~ Date, data=df_model_1)
df_model_1 <- add_predictions(data=df_model_1, model=model_1) %>% add_residuals(model=model_1)

m1 <- ggplot(data=df_model_1) + 
        geom_point(aes(x=Date, y=Close_btc)) +
        geom_line(data=df_model_1, aes(x=Date, y=pred), color='Blue', size=1.5) +
        theme(axis.line = element_line(colour = "black", size = 1), text = element_text(size = 30),
              plot.title = element_text(color="Black", size=30, face="bold")) +
        labs(x="width", y="length", title="Sepal length and width")
# Residual graph
m2 <- ggplot(data=df_model_1, aes(y = resid)) +
        geom_boxplot() +
        labs(title='Boxplot: Residuals', y='Residuals value') +
        theme(axis.line = element_line(colour = "black", size = 1), text = element_text(size = 40),
              plot.title = element_text(color="Black", size=40, face="bold"))

# %%
m1
# Out:
# plot without title

# %%
m2
# Out:
# plot without title

# %%
df_model_2 <- df_model_1
# First model
model_2 = lm(Close_btc ~ Date + Close_oro + Close_brent + Close_nasdaq, data=df_model_2)
df_model_2 <- add_predictions(data=df_model_2, model=model_2) %>% add_residuals(model=model_2)

m3 <- ggplot(data=df_model_2) + 
        geom_point(aes(x=Date, y=Close_btc)) +
        geom_line(data=df_model_2, aes(x=Date, y=pred), color='Blue', size=1.5) +
        theme(axis.line = element_line(colour = "black", size = 1), text = element_text(size = 30),
              plot.title = element_text(color="Black", size=30, face="bold")) +
        labs(x="width", y="length", title="Sepal length and width")
# Residual graph
m4 <- ggplot(data=df_model_2, aes(y = resid)) +
        geom_boxplot() +
        labs(title='Boxplot: Residuals', y='Residuals value') +
        theme(axis.line = element_line(colour = "black", size = 1), text = element_text(size = 40),
              plot.title = element_text(color="Black", size=40, face="bold"))

# %%
m3
# Out:
# plot without title

# %%
m4
# Out:
# plot without title

# %%
df_model_3 <- df_model_1
# First model
model_3 = lm(Close_btc ~ Date + Close_oro + Close_brent + Close_nasdaq, data=df_model_3)
df_model_3 <- add_predictions(data=df_model_3, model=model_3) %>% add_residuals(model=model_3)

m3 <- ggplot(data=df_model_3) + 
        geom_point(aes(x=Date, y=Close_btc)) +
        geom_line(data=df_model_3, aes(x=Date, y=pred), color='Blue', size=1.5) +
        theme(axis.line = element_line(colour = "black", size = 1), text = element_text(size = 30),
              plot.title = element_text(color="Black", size=30, face="bold")) +
        labs(x="width", y="length", title="Sepal length and width")
# Residual graph
m4 <- ggplot(data=df_model_3, aes(y = resid)) +
        geom_boxplot() +
        labs(title='Boxplot: Residuals', y='Residuals value') +
        theme(axis.line = element_line(colour = "black", size = 1), text = element_text(size = 40),
              plot.title = element_text(color="Black", size=40, face="bold"))
