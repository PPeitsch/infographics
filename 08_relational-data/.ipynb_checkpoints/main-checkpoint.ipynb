# %%
source("core.r")
# Out:
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.7     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# `summarise()` has grouped output by 'teamID'. You can override using the `.groups` argument.
# `summarise()` has grouped output by 'leagueID'. You can override using the `.groups` argument.
# `summarise()` has grouped output by 'leagueID'. You can override using the `.groups` argument.
# `summarise()` has grouped output by 'leagueID'. You can override using the `.groups` argument.
# `summarise()` has grouped output by 'leagueID'. You can override using the `.groups` argument.
# ...

# %%
head(best_10_goals, 10)
# Out:
#    teamID name                xGoals   shots shotsOnTarget deep total_goals
# 1  148    Barcelona           1.76141  10    4              5   698
# 2  161    Paris Saint Germain 1.33457   7    3              3   642
# 3  150    Real Madrid         1.54271  27    8             11   628
# 4  117    Bayern Munich       3.22904  23    9              6   628
# 5   88    Manchester City     1.9242   20    7              8   620
# 6  105    Napoli              1.15002  14    3              3   542
# 7   98    Juventus            1.82451  21    5             13   533
# 8   87    Liverpool           0.329873  8    3              5   519
# 9  129    Borussia Dortmund   2.42013  18    7              7   505
# 10  95    Roma                1.16312  20    7             11   499

# %%
p1
# Out:
# plot without title

# %%
head(best_10_shots, 10)
# Out:
#    teamID name            total_goals total_shots total_deep total_OnTarget
# 1  105    Napoli          542         4645        2216       1692
# 2   88    Manchester City 620         4609        3470       1664
# 3  150    Real Madrid     628         4463        2542       1746
# 4   87    Liverpool       519         4267        2879       1534
# 5  117    Bayern Munich   628         4261        2815       1708
# 6   95    Roma            499         4239        2195       1469
# 7   98    Juventus        533         4220        2029       1502
# 8  106    Inter           474         4144        2124       1400
# 9  148    Barcelona       698         4097        3495       1800
# 10  80    Chelsea         469         4065        2608       1436

# %%
p2
# Out:
# plot without title

# %%
head(teams_stats, 10)
# Out:
#    teamID name                total_goals total_shots total_deep total_OnTarget
# 1  148    Barcelona           698         4097        3495       1800
# 2  161    Paris Saint Germain 642         3836        2607       1588
# 3  117    Bayern Munich       628         4261        2815       1708
# 4  150    Real Madrid         628         4463        2542       1746
# 5   88    Manchester City     620         4609        3470       1664
# 6  105    Napoli              542         4645        2216       1692
# 7   98    Juventus            533         4220        2029       1502
# 8   87    Liverpool           519         4267        2879       1534
# 9  129    Borussia Dortmund   505         3503        2247       1355
# 10  95    Roma                499         4239        2195       1469

# %%
p3
# Out:
# plot without title

# %%
p4
# Out:
# plot without title

# %%
p5
# Out:
# plot without title

# %%
league_goals
# Out:
#   leagueID name           awayGoals_l homeGoals_l sumGoals
# 1 2        Serie A        3363        4113        7476
# 2 1        Premier League 3211        4002        7213
# 3 4        La Liga        3035        4037        7072
# 4 5        Ligue 1        2898        3758        6656
# 5 3        Bundesliga     2793        3531        6324

# %%
best_5_shooters
# Out:
#   playerID name               total_goals
# 1 2097     Lionel Messi       231
# 2 2371     Cristiano Ronaldo  215
# 3  227     Robert Lewandowski 203
# 4 2098     Luis Su�rez        168
# 5  647     Harry Kane         163

# %%
best_5_assiter
# Out:
#   assisterID assists name            total_asistencias
# 1 2099       1       Neymar          119
# 2 2098       1       Luis Su�rez      96
# 3  224       0       Thomas M�ller    95
# 4  447       0       Kevin De Bruyne  90
# 5 1250       0       Mohamed Salah    84

# %%
worst_players
# Out:
#   total player_name     rojas amarillas
# 1 22.00 �lvaro Gonz�lez 4     72
# 2 22.00 Dani Garc�a     2     80
# 3 21.75 Dami�n Su�rez   4     71
# 4 21.25 Granit Xhaka    7     57
# 5 20.50 Yannick Cahuzac 9     46
