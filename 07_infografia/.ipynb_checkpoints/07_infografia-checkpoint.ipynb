# %% [markdown]
# #### **07 Infografía - Flights Dataset**
# ___
# ##### **Autor:** Peitsch, Pablo
# ##### **Github:** <a href="https://github.com/PPeitsch">@PPeitsch</a> **Fecha:** 2022-10-16

# %%
source('process.r')
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.7     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘reshape2’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths
#
#
#
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
# Warning message in carrier == c("OO", "YV", "HA", "FL", "F9", "AS", "9E"):
# “longer object length is not a multiple of shorter object length”
# `summarise()` has grouped output by 'month'. You can override using the
# `.groups` argument.

# %% [markdown]
# ##### En principio, se estudian debajo en conjunto las demoras de despegue y arribo para todas las companías con un gráfico tipo violín. Se puede observar en la Fig. 1 que, si bien hay retrasos significativos, no son de mayor peso, mayormente incluso parten antes y llegan antes.

# %%
# Cambia tamaño del plot
options(repr.plot.width=25, repr.plot.height=5)
p1
# Out:
# Warning message:
# “Removed 17685 rows containing non-finite values (stat_ydensity).”
# plot without title

# %% [markdown]
# ##### **_Figura 1._** Distribución del retraso en partidas y arribos de los vuelos para las distintas compañías en el año 2013.

# %% [markdown]
# ##### Otra forma de evaluar el conjunto de estos datos es mediante un  gráfico de densidad. En este caso, en la Fig. 2, se grafica lo mismo, rellenando por color según el mes. Aquí se puede ver claramente que hay un retraso significativo en ciertos meses del año para la compañía OO, y pareciera un retraso generalizado, aunque con menor peso, para otras compañías como YV, HA, FL, F9, AS y 9E. De todas formas, los retrasos no parecieran extenderse por más de 8min. Veamos qué sucede con estas compañías.

# %%
# Cambia tamaño del plot
options(repr.plot.width=20, repr.plot.height=12)
p2
# Out:
# Picking joint bandwidth of 0.0779
#
# Warning message:
# “Removed 17685 rows containing non-finite values (stat_density_ridges).”
# plot without title

# %% [markdown]
# ##### **_Figura 2._** Distribución del retraso en partidas y arribos de los vuelos para las distintas compañías en el año 2013, evaluados por mes.

# %%
# Cambia tamaño del plot
options(repr.plot.width=20, repr.plot.height=12)
grid.arrange(p3, p4)
# Out:
# Warning message:
# “Removed 156 rows containing non-finite values (stat_boxplot).”
# Warning message:
# “Removed 175 rows containing non-finite values (stat_boxplot).”
# plot without title

# %% [markdown]
# ##### **_Figura 3._** Distribución del retraso en partidas y arribos de los vuelos para las compañías OO, YV, HA, FL, F9, AS y 9E, en el año 2013 evaluados por mes.

# %%
flights_metricas
# Out:
#    month carrier media_arr_delay media_dep_delay mediana_arr_delay
# 1   1    FL      0.05529835      0.03287037      -0.01666667
# 2   2    FL      0.07080378      0.08634752       0.00000000
# 3   3    FL      0.26886689      0.27667767       0.03333333
# 4   4    FL      0.32183718      0.21534653       0.13333333
# 5   5    FL      0.30553830      0.31972050       0.05000000
# 6   6    FL      0.69944675      0.63409405       0.26666667
# 7   7    FL      0.74946237      0.69576613       0.19166667
# 8   8    FL      0.41392157      0.39091503       0.15000000
# 9   9    FL      0.25118577      0.28399209       0.00000000
# 10 10    FL      0.26652422      0.22799145       0.13333333
# 11 11    FL      0.30899340      0.28110561       0.13333333
# 12 12    FL      0.48509615      0.43509615       0.18333333
#    mediana_dep_delay sd_arr_delay sd_dep_delay
# 1  -0.06666667       0.4711931    0.3958904
# 2  -0.01666667       0.3917201    0.3194898
# 3   0.01666667       0.8318379    0.8074915
# 4  -0.01666667       0.7713701    0.7314634
# 5   0.00000000       0.9046979    0.8680894
# 6   0.16666667       1.1166676    1.0707055
# 7   0.10000000       1.4164304    1.4146544
# 8   0.08333333       0.8484618    0.8485264
# 9  -0.01666667       1.1300249    1.1500305
# 10  0.05000000       0.6058115    0.6145383
# 11  0.10000000       0.6989491    0.6118299
# 12  0.13333333       0.9812614    0.9570091

# %% [markdown]
# #### ***Figura 5.*** Distribución del retraso en partidas y arribos de los vuelos para la compañía 9E en el año 2013, evaluada por mes.
