# %% [markdown]
# #### **Análisis de vuelos de 2013 en EEUU**
# ___
# ##### **Autor:** Peitsch, Pablo    **Github:** <a href="https://github.com/PPeitsch/07_infografia">@PPeitsch</a>    **Email:** <a href="mailto:preynosopeitsch@estudiantes.unsam.edu.ar">preynosopeitsch@estudiantes.unsam.edu.ar</a>    **Fecha:** 2022-11-16

# %%
source('process.r')
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘reshape2’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths
#
#
# Warning message:
# “The `size` argument of `element_line()` is deprecated as of ggplot2 3.4.0.
# ℹ Please use the `linewidth` argument instead.”
# `summarise()` has grouped output by 'dest', 'lat'. You can override using the
# `.groups` argument.

# %% [markdown]
# #### **Introducción**
# ___
# ##### En este documento se hace un breve análisis del set de datos de vuelos de ciudad de Nueva York de 2013 (nycflights13), que se encuentra disponible como paquete en los repositorios de R. Los datos se encuentran distribuidos en cinco dataframes. A las compañías les interesa saber con los datos obtenidos si es posible determinar a qué se deben los retrasos de sus vuelos en los distintos aeropuertos y si es posible evitarlos.

# %% [markdown]
# ##### En la Fig. 1, se muestra la estructura del set de datos y cómo se relacionan los dataframes mediante sus claves primarias y foráneas.

# %% [markdown]
# ##### **_Figura 1._** Relación entre los dataframes, claves foráneas y primarias.

# %% [markdown]
# ##### Con media de retrasos y distancia recorrida de los vuelos por las distintas compañías para luego  evaluar si existe correlación. Fig. 2.

# %%
options(repr.plot.width=24, repr.plot.height=6)
jpeg(file=file.path(fig_folder, fig1_name), width=1200, height=300)
p1
dev.off()
# Out:
# png
#   2

# %%
p1
# Out:
# plot without title

# %%
options(repr.plot.width=26, repr.plot.height=13)
jpeg(file=file.path(fig_folder, fig2_name), width=1200, height=300)
p2
dev.off()
# Out:
# png
#   2

# %%
p2
# Out:
# plot without title

# %% [markdown]
# ##### **_Figura 2._  a.** Retrasos en partida y arribo; **b.** Distancia  recorrida, evaluados por aerolínea para todos los aeropuertos.

# %%
options(repr.plot.width=26, repr.plot.height=13)
jpeg(file=file.path(fig_folder, fig3_name), width=1200, height=600)
p3
dev.off()
# Out:
# png
#   2

# %%
p3
# Out:
# plot without title

# %% [markdown]
# ##### **_Figura 3._** Distancia recorrida por los vuelos  de las distintas compañías

# %% [markdown]
# regresion retrasos vs distancia  para cada aerolinea
# retrasos en el mapa

# %%
options(repr.plot.width=26, repr.plot.height=13)
jpeg(file=file.path(fig_folder, fig4_name), width=1200, height=600)
p4
dev.off()
# Out:
# png
#   2

# %%
p4
# Out:
# plot without title

# %% [markdown]
# ##### **_Figura 4._** Distribución espacial aeropuertos EEUU.

# %%
flights_airports <- inner_join(flights, airports, by = c("dest" = "faa")) %>%
    group_by(dest, lat, lon) %>%
    summarize(avg_dep_delay = mean(dep_delay, na.rm = TRUE), count_dep = n())

# %%
install.packages("viridis")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
library(viridis)
# Out:
# Loading required package: viridisLite

# %%
p5 <- ggplot(data=flights_airports, aes(x=lon, y=lat, color=avg_dep_delay, size=count_dep)) + 
    geom_point() +
    labs(x='Longitud (°)', y="Latitud (°)", color="Retrasos(min)") +
    scale_y_continuous(limits = c(min(flights_airports$lat)-1, 50)) +
    scale_x_continuous(limits = c(-135, max(flights_airports$lon)+1)) +
    scale_size_continuous(range = c(5,30)) +
    scale_color_viridis(option = "D") +
    theme(axis.line = element_line(colour = "black", size = 1), text = element_text(size = 35))
fig5_name <- "fig5.jpeg"

# %%
options(repr.plot.width=26, repr.plot.height=13)
jpeg(file=file.path(fig_folder, fig5_name), width=1200, height=600)
p5
dev.off()
# Out:
# Warning message:
# “Removed 2 rows containing missing values (`geom_point()`).”
# png
#   2

# %%
p5
# Out:
# Warning message:
# “Removed 2 rows containing missing values (`geom_point()`).”
# plot without title
